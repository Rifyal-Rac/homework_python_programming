# %% [markdown]
# # Basic Python Programming
# Auth : Rifyal Rachmat<br>
# Loca : Kupang<br>
# Desc : This homework basic python Programming

# %%
#Import numpy, panda, and dataset - located local D
import pandas as pd
import numpy as np
pd.DataFrame()
google_play_apps = pd.read_csv(r"D:\dataset\googleplaystore.csv")
google_play_apps.dtypes
google_play_apps["Category"].value_counts()

# How many unique apps categories reflected in the dataset? 
google_play_apps["Category"].describe()
# Out:
# count      10841
# unique        34
# top       FAMILY
# freq        1972
# Name: Category, dtype: object

# %%
#How many unique genres according to the dataset?
google_play_apps["Genres"].describe()
# Out:
# count     10841
# unique      120
# top       Tools
# freq        842
# Name: Genres, dtype: object

# %%
# remove duplicates
google_play_apps.drop_duplicates(subset='App', inplace=True)

# %%
google_play_apps.describe()
# Out:
#             Rating
# count  8197.000000
# mean      4.175052
# std       0.561026
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# check  "free"
google_play_apps[google_play_apps['Installs']=='Free']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
google_play_apps = google_play_apps[google_play_apps['Installs'] != 'Free']

# %%
# remove "+" and "," at column that contain "free"
google_play_apps['Installs'] =google_play_apps['Installs'].apply(lambda x: x.replace( '+' , '') if '+' in str(x) else x)
google_play_apps['Installs'] =google_play_apps['Installs'].apply(lambda x: x.replace( ',' , '') if ',' in str(x) else x)
google_play_apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
# data types before
google_play_apps.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# conver data type to integer (int)
google_play_apps ['Installs'] = google_play_apps ['Installs'] .astype( int )
google_play_apps.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Unique Columns
google_play_apps_cat=google_play_apps[(google_play_apps['App']=="DU Battery Saver - Battery Charger & Battery Life")|(google_play_apps['App']=="File Commander - File Manager/Explorer")|(google_play_apps['App']=="Subway Surfers")|(google_play_apps['App']=="Flipboard: News For Our Time")|(google_play_apps['App']=="Pinterest")|(google_play_apps['App']=="Dropbox")|(google_play_apps['App']=="WhatsApp Messenger")|(google_play_apps['App']=="FIFA Soccer")]
google_play_apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
# make new column for category of users < 1000000000 for all dataset (trial)
google_play_apps['Score_group']=np.where(google_play_apps['Installs']>=1000000000,'>1Bio','< 1Bio')

google_play_apps_cat
# Out:
#                                                      App            Category  \
# 336                                   WhatsApp Messenger       COMMUNICATION
# 1654                                      Subway Surfers                GAME
# 2552                                           Pinterest              SOCIAL
# 3473                                             Dropbox        PRODUCTIVITY
# 3755                        Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 8445                                         FIFA Soccer              SPORTS
# 8896   DU Battery Saver - Battery Charger & Battery Life               TOOLS
# 10253             File Commander - File Manager/Explorer            BUSINESS
#
#        Rating   Reviews                Size    Installs  Type Price  \
# 336       4.4  69119316  Varies with device  1000000000  Free     0
# 1654      4.5  27722264                 76M  1000000000  Free     0
# 2552      4.6   4305441  Varies with device   100000000  Free     0
# ...

# %%
#Category Focused
google_play_apps_test1=google_play_apps[(google_play_apps['App']=="WhatsApp Messenger")|(google_play_apps['App']=="Google Duo - High Quality Video Calls")|(google_play_apps['App']=="Skype - free IM & video calls")|(google_play_apps['App']=="Facebook")]

google_play_apps_test1

google_play_apps_test1[google_play_apps_test1['Installs']<1000000000]
# Out:
#                                        App       Category  Rating  Reviews  \
# 371  Google Duo - High Quality Video Calls  COMMUNICATION     4.6  2083237
#
#                    Size   Installs  Type Price Content Rating         Genres  \
# 371  Varies with device  500000000  Free     0       Everyone  Communication
#
#       Last Updated               Current Ver Android Ver Score_group
# 371  July 31, 2018  37.1.206017801.DR37_RC14  4.4 and up      < 1Bio

# %%
# Rank of category communication
google_play_apps_category= google_play_apps[(google_play_apps['Category'] == "COMMUNICATION")]
google_play_apps_category
# Out:
#                                                     App       Category  \
# 335            Messenger – Text and Video Chat for Free  COMMUNICATION
# 336                                  WhatsApp Messenger  COMMUNICATION
# 337                                   Messenger for SMS  COMMUNICATION
# 338                        Google Chrome: Fast & Secure  COMMUNICATION
# 339               Messenger Lite: Free Calls & Messages  COMMUNICATION
# 340                                               Gmail  COMMUNICATION
# 341                                            Hangouts  COMMUNICATION
# 342                                     Viber Messenger  COMMUNICATION
# 343                                            My Tele2  COMMUNICATION
# 344                      Firefox Browser fast & private  COMMUNICATION
# 345                         Yahoo Mail – Stay Organized  COMMUNICATION
# 346                        imo beta free calls and text  COMMUNICATION
# ...

# %%
# change to integer
google_play_apps_category['Reviews'] = google_play_apps_category['Reviews'].astype (int)
google_play_apps_category.dtypes
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size               object
# Installs            int32
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# Score_group        object
# dtype: object

# %%
#Sort Value Reviews of communication Apps
google_play_apps_category_sort=google_play_apps_category.sort_values(['Reviews'], ascending = False)
#google_play_apps_category_sort by category needed

google_play_apps_test1=google_play_apps[(google_play_apps['App']=="WhatsApp Messenger")|(google_play_apps['App']=="BBM - Free Calls & Messages")|(google_play_apps['App']=="Viber Messenger")|(google_play_apps['App']=="LINE: Free Calls & Messages")|(google_play_apps['App']=="Skype - free IM & video calls")]
google_play_apps_test1
# Out:
#                                App       Category  Rating   Reviews  \
# 336             WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 342                Viber Messenger  COMMUNICATION     4.3  11334799
# 391  Skype - free IM & video calls  COMMUNICATION     4.1  10484169
# 403    LINE: Free Calls & Messages  COMMUNICATION     4.2  10790289
# 406    BBM - Free Calls & Messages  COMMUNICATION     4.3  12842860
#
#                    Size    Installs  Type Price Content Rating         Genres  \
# 336  Varies with device  1000000000  Free     0       Everyone  Communication
# 342  Varies with device   500000000  Free     0       Everyone  Communication
# 391  Varies with device  1000000000  Free     0       Everyone  Communication
# 403  Varies with device   500000000  Free     0       Everyone  Communication
# 406  Varies with device   100000000  Free     0       Everyone  Communication
#
#        Last Updated         Current Ver         Android Ver Score_group
# ...

# %%
#10 google_play_apps_rating_game=google_play_apps[google_play_apps['Category']=="GAME"]
google_play_apps_rating_game=google_play_apps[google_play_apps['Category']=="GAME"]
google_play_apps_rating_game_sort=google_play_apps_rating_game.sort_values(['Installs','Rating'], ascending = False)
google_play_apps_rating_game_sort.head(3)
# Out:
#                    App Category  Rating   Reviews                Size  \
# 1654    Subway Surfers     GAME     4.5  27722264                 76M
# 1722    My Talking Tom     GAME     4.5  14891223  Varies with device
# 1655  Candy Crush Saga     GAME     4.4  22426677                 74M
#
#         Installs  Type Price Content Rating  Genres   Last Updated  \
# 1654  1000000000  Free     0   Everyone 10+  Arcade  July 12, 2018
# 1722   500000000  Free     0       Everyone  Casual  July 19, 2018
# 1655   500000000  Free     0       Everyone  Casual   July 5, 2018
#
#      Current Ver Android Ver Score_group
# 1654      1.90.0  4.1 and up       >1Bio
# 1722   4.8.0.132  4.1 and up      < 1Bio
# 1655   1.129.0.2  4.1 and up      < 1Bio
